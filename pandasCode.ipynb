# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

student={
    "name":["Tam","Nad","Mad","Sad","Bad"],
    "age":[20,21,22,23,24]
}
af =pd.DataFrame(student)
af.tail()
#print("\n")
#af.tail(2)
# Out:
#   name  age
# 0  Tam   20
# 1  Nad   21
# 2  Mad   22
# 3  Sad   23
# 4  Bad   24

# %%
#af.tail(2)
af.sort_values(by="name")
# Out:
#   name  age
# 4  Bad   24
# 2  Mad   22
# 1  Nad   21
# 3  Sad   23
# 0  Tam   20

# %%
pd.read_csv("Expense_Income_Tracker.csv")
# Out:
#        Type       Expense Category  Amount            Description       Date
# 0    Income                 Salary   50000            Work salary   8/1/2023
# 1    Income             RD retruns    5000   Bank Deposit returns   8/2/2023
# 2    Income                Returns     500           From Friends   8/3/2023
# 3   Expense            Dinning Out     120        Had 1 Bririyani   8/4/2023
# 4   Expense          Entertainment     120                  Movie   8/5/2023
# 5   Expense          Miscellaneous     600            Buying Gift   8/6/2023
# 6   Expense             Grocerries     800  Fruits and Vegetables   8/7/2023
# 7   Expense              Clothings   1,200                1 shirt   8/8/2023
# 8   Expense                 Travel     500            To Hometown   8/9/2023
# 9   Expense          Entertainment   2,500                   Club  8/10/2023
# 10  Expense                   Rent  10,000             House Rent  8/11/2023
# ...

# %%
af.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
af.describe()
# Out:
#              age
# count   5.000000
# mean   22.000000
# std     1.581139
# min    20.000000
# 25%    21.000000
# 50%    22.000000
# 75%    23.000000
# max    24.000000

# %%
pip install matplotlib
# Out:
# ...
#                                               0.0/7.6 MB ? eta -:--:--
#                                               0.1/7.6 MB 3.0 MB/s eta 0:00:03
#      -                                        0.2/7.6 MB 2.5 MB/s eta 0:00:03
#      -                                        0.3/7.6 MB 3.0 MB/s eta 0:00:03
#      --                                       0.4/7.6 MB 2.3 MB/s eta 0:00:04
#      --                                       0.4/7.6 MB 2.3 MB/s eta 0:00:04
#      ---                                      0.6/7.6 MB 2.1 MB/s eta 0:00:04
#      ---                                      0.7/7.6 MB 2.1 MB/s eta 0:00:04
#      ---                                      0.7/7.6 MB 1.8 MB/s eta 0:00:04
#      ----                                     0.8/7.6 MB 2.0 MB/s eta 0:00:04
#      ----                                     0.9/7.6 MB 2.0 MB/s eta 0:00:04
#      -----                                    1.0/7.6 MB 1.9 MB/s eta 0:00:04
# ...

# %%
af['age'].hist()
# Out:
# <Axes: >
